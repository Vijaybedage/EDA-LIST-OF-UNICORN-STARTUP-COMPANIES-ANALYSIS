# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaybedage/EDA-LIST-OF-UNICORN-STARTUP-COMPANIES-ANALYSIS/blob/main/PROJECT_1_List_of_Unicorn__Startup_Companies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project Title: list_of_unicorn_Startup_Compaines analysis

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## read_csv of "List_of_Unicorn _Startup_Companies.csv"

# %%
sp = pd.read_csv("List_of_Unicorn _Startup_Companies.csv")
sp
# Out:
#      Unnamed: 0         Company Valuation(US$ billions)      Valuation date  \
# 0             0       ByteDance                     140       June 2022[13]
# 1             1          SpaceX                     127       June 2022[13]
# 2             2           Shein                     100       June 2022[13]
# 3             3          Stripe                      50      March 2023[13]
# 4             4           Canva                      40  September 2021[16]
# ..          ...             ...                     ...                 ...
# 653         653             Voi                      1+      April 2022[59]
# 654         654   Neo Financial                       1       May 2022[567]
# 655         655  Physics Wallah                     1.1      June 2022[568]
# 656         656         OneCard                    1.4+      July 2022[569]
# 657         657            5ire                    1.5+      July 2022[570]
#
#                    Industry Country/countries  \
# ...

# %%
top10 = sp.iloc[ :10]

#under_100_sp=sp[sp['Valuation(US$ billions)']>100]
#under_100_sp

# %% [markdown]
# in this below we taken under 100 US$ earing found

# %% [markdown]
# ## now droping nullvalues and plotig bar chart for company and valuations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = top10['Company']
y = top10['Valuation(US$ billions)']
plt.bar(x,y)

plt.xticks(rotation =30)
plt.show()

# %% [markdown]
# ## 🤺🤺in this below we taking head(),tail() AND taking spific colunm in head() and tail()🤺🤺

# %%
sp.head()
# Out:
#    Unnamed: 0    Company Valuation(US$ billions)      Valuation date  \
# 0           0  ByteDance                     140       June 2022[13]
# 1           1     SpaceX                     127       June 2022[13]
# 2           2      Shein                     100       June 2022[13]
# 3           3     Stripe                      50      March 2023[13]
# 4           4      Canva                      40  September 2021[16]
#
#              Industry Country/countries  \
# 0            Internet             China
# 1           Aerospace                US
# 2          E-commerce             China
# 3  Financial services      US / Ireland
# 4      Graphic design         Australia
#
#                                          Founder(s)
# 0                          Zhang Yiming, Liang Rubo
# 1                                         Elon Musk
# 2                                          Chris Xu
# 3                         Patrick and John Collison
# ...

# %%
sp.tail()
# Out:
#      Unnamed: 0         Company Valuation(US$ billions)  Valuation date  \
# 653         653             Voi                      1+  April 2022[59]
# 654         654   Neo Financial                       1   May 2022[567]
# 655         655  Physics Wallah                     1.1  June 2022[568]
# 656         656         OneCard                    1.4+  July 2022[569]
# 657         657            5ire                    1.5+  July 2022[570]
#
#                    Industry Country/countries  \
# 653                     NaN            Sweden
# 654    Financial technology            Canada
# 655  Educational technology             India
# 656    Financial technology             India
# 657              Technology             India
#
#                                     Founder(s)
# 653                                        NaN
# 654       Andrew Chau, Jeff Adamson, Kris Read
# 655                               Alakh Pandey
# 656  Anurag Sinha, Rupesh Kumar, Vaibhav Hathi
# ...

# %%
print(sp.head()[['Country/countries','Company','Industry','Founder(s)']])
# Out:
#   Country/countries    Company            Industry  \
# 0             China  ByteDance            Internet
# 1                US     SpaceX           Aerospace
# 2             China      Shein          E-commerce
# 3      US / Ireland     Stripe  Financial services
# 4         Australia      Canva      Graphic design
#
#                                          Founder(s)
# 0                          Zhang Yiming, Liang Rubo
# 1                                         Elon Musk
# 2                                          Chris Xu
# 3                         Patrick and John Collison
# 4  Melanie Perkins, Clifford Obrecht, Cameron Adams

# %%
print(sp.tail()[['Country/countries','Company','Industry','Founder(s)']])
# Out:
#     Country/countries         Company                Industry  \
# 653            Sweden             Voi                     NaN
# 654            Canada   Neo Financial    Financial technology
# 655             India  Physics Wallah  Educational technology
# 656             India         OneCard    Financial technology
# 657             India            5ire              Technology
#
#                                     Founder(s)
# 653                                        NaN
# 654       Andrew Chau, Jeff Adamson, Kris Read
# 655                               Alakh Pandey
# 656  Anurag Sinha, Rupesh Kumar, Vaibhav Hathi
# 657                               Pratik Gauri

# %%
print(sp.head()[['Country/countries','Company','Industry','Founder(s)']])
# Out:
#   Country/countries    Company            Industry  \
# 0             China  ByteDance            Internet
# 1                US     SpaceX           Aerospace
# 2             China      Shein          E-commerce
# 3      US / Ireland     Stripe  Financial services
# 4         Australia      Canva      Graphic design
#
#                                          Founder(s)
# 0                          Zhang Yiming, Liang Rubo
# 1                                         Elon Musk
# 2                                          Chris Xu
# 3                         Patrick and John Collison
# 4  Melanie Perkins, Clifford Obrecht, Cameron Adams

# %%
print(sp.tail())
# Out:
#      Unnamed: 0         Company Valuation(US$ billions)  Valuation date  \
# 653         653             Voi                      1+  April 2022[59]
# 654         654   Neo Financial                       1   May 2022[567]
# 655         655  Physics Wallah                     1.1  June 2022[568]
# 656         656         OneCard                    1.4+  July 2022[569]
# 657         657            5ire                    1.5+  July 2022[570]
#
#                    Industry Country/countries  \
# 653                     NaN            Sweden
# 654    Financial technology            Canada
# 655  Educational technology             India
# 656    Financial technology             India
# 657              Technology             India
#
#                                     Founder(s)
# 653                                        NaN
# 654       Andrew Chau, Jeff Adamson, Kris Read
# 655                               Alakh Pandey
# 656  Anurag Sinha, Rupesh Kumar, Vaibhav Hathi
# ...

# %% [markdown]
# # 🤷‍♀️and in this below duplicating, isnull().sum()*100, iloc() for some range and iloc for spific row and column and
# # sp.loc[1,"Country/countries"]="India" is taking locating🤷‍♀️

# %%
sp.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 653    False
# 654    False
# 655    False
# 656    False
# 657    False
# Length: 658, dtype: bool

# %%
( sp.isnull().sum() )  * 100
# Out:
# Unnamed: 0                     0
# Company                        0
# Valuation(US$ billions)        0
# Valuation date                 0
# Industry                    6400
# Country/countries              0
# Founder(s)                 52000
# dtype: int64

# %%
sp.iloc[1:80]
# Out:
#     Unnamed: 0              Company Valuation(US$ billions)  \
# 1            1               SpaceX                     127
# 2            2                Shein                     100
# 3            3               Stripe                      50
# 4            4                Canva                      40
# 5            5         Checkout.com                      40
# ..         ...                  ...                     ...
# 75          75             Ola Cabs                     7.3
# 76          76             Scale AI                     7.3
# 77          77                 Gong                    7.25
# 78          78          TripActions                    7.25
# 79          79  Automation Anywhere                     6.8
#
#         Valuation date                    Industry Country/countries  \
# 1        June 2022[13]                   Aerospace                US
# 2        June 2022[13]                  E-commerce             China
# ...

# %%
# specific rows
print(sp.iloc[[1,655,3],[1,6,2]])
# Out:
#             Company                 Founder(s) Valuation(US$ billions)
# 1            SpaceX                  Elon Musk                     127
# 655  Physics Wallah               Alakh Pandey                     1.1
# 3            Stripe  Patrick and John Collison                      50

# %%
print("Rows where score is missing:")
print(sp[sp['Industry'].isnull()])
# Out:
# Rows where score is missing:
#      Unnamed: 0            Company Valuation(US$ billions)  \
# 349         349  Taihe Music Group                     1.7
# 362         362    Caocao Zhuanche                     1.6
# 373         373            CureFit                    1.56
# 374         374          HeartFlow                    1.5+
# 375         375          Aihuishou                     1.5
# ..          ...                ...                     ...
# 638         638    Yitu Technology                      1+
# 641         641       Zhaogang.com                      1+
# 642         642         Zhuanzhuan                      1+
# 643         643          Zuoyebang                      1+
# 653         653                Voi                      1+
#
#          Valuation date Industry Country/countries  \
# 349      June 2018[124]      NaN             China
# 362   January 2018[124]      NaN             China
# 373  November 2021[339]      NaN             India
# ...

# %%
print("\n rename  the country us as to indiaa in row :")
sp.loc[1,"Country/countries"]="India"
sp
# Out:
#  rename  the country us as to indiaa in row :
#      Unnamed: 0         Company Valuation(US$ billions)      Valuation date  \
# 0             0       ByteDance                     140       June 2022[13]
# 1             1          SpaceX                     127       June 2022[13]
# 2             2           Shein                     100       June 2022[13]
# 3             3          Stripe                      50      March 2023[13]
# 4             4           Canva                      40  September 2021[16]
# ..          ...             ...                     ...                 ...
# 653         653             Voi                      1+      April 2022[59]
# 654         654   Neo Financial                       1       May 2022[567]
# 655         655  Physics Wallah                     1.1      June 2022[568]
# 656         656         OneCard                    1.4+      July 2022[569]
# 657         657            5ire                    1.5+      July 2022[570]
#
# ...

# %%
sp.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 653    False
# 654    False
# 655    False
# 656    False
# 657    False
# Length: 658, dtype: bool

# %%
sp.describe()
# Out:
#        Unnamed: 0
# count  658.000000
# mean   328.500000
# std    190.092521
# min      0.000000
# 25%    164.250000
# 50%    328.500000
# 75%    492.750000
# max    657.000000

# %%
sp.duplicated("Company")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 653    False
# 654    False
# 655    False
# 656    False
# 657    False
# Length: 658, dtype: bool

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               658 non-null    int64
#  1   Company                  658 non-null    object
#  2   Valuation(US$ billions)  658 non-null    object
#  3   Valuation date           658 non-null    object
#  4   Industry                 594 non-null    object
#  5   Country/countries        658 non-null    object
#  6   Founder(s)               138 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 36.1+ KB

# %%
print(sp[sp['Valuation date'].isnull()])
# print(sp[sp['Valuation(US$ billions)'].between(1,2)])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Company, Valuation(US$ billions), Valuation date, Industry, Country/countries, Founder(s)]
# Index: []

# %%
sp['Valuation(US$ billions)'] = pd.to_numeric(sp['Valuation(US$ billions)'], errors='coerce')

# %%
earning_between_1_to_2_sp =  sp[sp['Valuation(US$ billions)'].between(1,2)]
earning_between_1_to_2_sp
# Out:
#      Unnamed: 0         Company  Valuation(US$ billions)      Valuation date  \
# 243         243      Deliverect                     1.40   January 2022[235]
# 288         288            Hive                     2.00     April 2021[278]
# 289         289           Mural                     2.00      July 2021[279]
# 290         290           Aiven                     2.00   October 2021[280]
# 291         291       AppsFlyer                     2.00  November 2020[281]
# ..          ...             ...                      ...                 ...
# 648         648        Ecovadis                     1.00     August 2022[94]
# 649         649         Scandit                     1.00  February 2022[564]
# 652         652         Einride                     1.44      April 2022[59]
# 654         654   Neo Financial                     1.00       May 2022[567]
# 655         655  Physics Wallah                     1.10      June 2022[568]
#
# ...

# %%
sp["Valuation(US$ billions)"].describe()
# Out:
# count    480.000000
# mean       5.120042
# std       10.916350
# min        1.000000
# 25%        1.590000
# 50%        2.600000
# 75%        5.000000
# max      140.000000
# Name: Valuation(US$ billions), dtype: float64

# %%
sp.head()[['Company', 'Founder(s)', 'Industry']].apply(lambda row: print(row['Company'], row['Founder(s)'], row['Industry']), axis=1)
# Out:
# ByteDance Zhang Yiming, Liang Rubo Internet
# SpaceX Elon Musk Aerospace
# Shein Chris Xu E-commerce
# Stripe Patrick and John Collison Financial services
# Canva Melanie Perkins, Clifford Obrecht, Cameron Adams Graphic design
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# dtype: object

# %% [markdown]
# ##    ❌❌❌❌❌❌❌❌ some errors❌❌❌❌❌❌❌

# %%
# # ❌
# sp = pd.DataFrame(sp)
# for index, row in sp.head().iterrows():
#    print(row['Company','Founder(s)'], row['Industry'])

#     #it not needed
# # ❌
